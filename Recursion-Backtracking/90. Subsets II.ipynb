# %% [markdown]
# <h2><a href="https://leetcode.com/problems/subsets-ii">90. Subsets II</a></h2><h3>Medium</h3><hr><p>Given an integer array <code>nums</code> that may contain duplicates, return <em>all possible</em> <span data-keyword="subset"><em>subsets</em></span><em> (the power set)</em>.</p>
#
# <p>The solution set <strong>must not</strong> contain duplicate subsets. Return the solution in <strong>any order</strong>.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
# <pre><strong>Input:</strong> nums = [1,2,2]
# <strong>Output:</strong> [[],[1],[1,2],[1,2,2],[2],[2,2]]
# </pre><p><strong class="example">Example 2:</strong></p>
# <pre><strong>Input:</strong> nums = [0]
# <strong>Output:</strong> [[],[0]]
# </pre>
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= nums.length &lt;= 10</code></li>
# 	<li><code>-10 &lt;= nums[i] &lt;= 10</code></li>
# </ul>

# %% [markdown]
# ![image.png](attachment:0b17cf8a-f53c-483d-814c-1a3d082f0c37.png)

# %%
from typing import List
class Solution:
    def subsetsWithDup(self, nums: List[int]) -> List[List[int]]:
        def backtrack(index, result, current):
            result.append(current[:])
            print(f"result: {result}")

            for i in range(index, len(nums)):
                if i > index and nums[i] == nums[i-1]:
                    continue
                current.append(nums[i])
                print(f"current: {current}, index : {i}")
                backtrack(i+1, result, current)
                current.pop()
                print(f"After popping current: {current}")

        result = []
        nums.sort()
        backtrack(0, result, [])
        return result

# %%
nums = [1,2,2]
sol = Solution()
sol.subsetsWithDup(nums)
# Out:
# result: [[]]
# current: [1], index : 0
# result: [[], [1]]
# current: [1, 2], index : 1
# result: [[], [1], [1, 2]]
# current: [1, 2, 2], index : 2
# result: [[], [1], [1, 2], [1, 2, 2]]
# After popping current: [1, 2]
# After popping current: [1]
# After popping current: []
# current: [2], index : 1
# result: [[], [1], [1, 2], [1, 2, 2], [2]]
# current: [2, 2], index : 2
# result: [[], [1], [1, 2], [1, 2, 2], [2], [2, 2]]
# After popping current: [2]
# After popping current: []
# [[], [1], [1, 2], [1, 2, 2], [2], [2, 2]]

# %%
nums = [1,2,2, 3,3]
sol = Solution()
sol.subsetsWithDup(nums)
# Out:
# result: [[]]
# current: [1], index : 0
# result: [[], [1]]
# current: [1, 2], index : 1
# result: [[], [1], [1, 2]]
# current: [1, 2, 2], index : 2
# result: [[], [1], [1, 2], [1, 2, 2]]
# current: [1, 2, 2, 3], index : 3
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3]]
# current: [1, 2, 2, 3, 3], index : 4
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3]]
# After popping current: [1, 2, 2, 3]
# After popping current: [1, 2, 2]
# After popping current: [1, 2]
# current: [1, 2, 3], index : 3
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3]]
# current: [1, 2, 3, 3], index : 4
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3], [1, 2, 3, 3]]
# After popping current: [1, 2, 3]
# After popping current: [1, 2]
# After popping current: [1]
# current: [1, 3], index : 3
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3], [1, 2, 3, 3], [1, 3]]
# current: [1, 3, 3], index : 4
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3], [1, 2, 3, 3], [1, 3], [1, 3, 3]]
# After popping current: [1, 3]
# After popping current: [1]
# After popping current: []
# current: [2], index : 1
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3], [1, 2, 3, 3], [1, 3], [1, 3, 3], [2]]
# current: [2, 2], index : 2
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3], [1, 2, 3, 3], [1, 3], [1, 3, 3], [2], [2, 2]]
# current: [2, 2, 3], index : 3
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3], [1, 2, 3, 3], [1, 3], [1, 3, 3], [2], [2, 2], [2, 2, 3]]
# current: [2, 2, 3, 3], index : 4
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3], [1, 2, 3, 3], [1, 3], [1, 3, 3], [2], [2, 2], [2, 2, 3], [2, 2, 3, 3]]
# After popping current: [2, 2, 3]
# After popping current: [2, 2]
# After popping current: [2]
# current: [2, 3], index : 3
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3], [1, 2, 3, 3], [1, 3], [1, 3, 3], [2], [2, 2], [2, 2, 3], [2, 2, 3, 3], [2, 3]]
# current: [2, 3, 3], index : 4
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3], [1, 2, 3, 3], [1, 3], [1, 3, 3], [2], [2, 2], [2, 2, 3], [2, 2, 3, 3], [2, 3], [2, 3, 3]]
# After popping current: [2, 3]
# After popping current: [2]
# After popping current: []
# current: [3], index : 3
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3], [1, 2, 3, 3], [1, 3], [1, 3, 3], [2], [2, 2], [2, 2, 3], [2, 2, 3, 3], [2, 3], [2, 3, 3], [3]]
# current: [3, 3], index : 4
# result: [[], [1], [1, 2], [1, 2, 2], [1, 2, 2, 3], [1, 2, 2, 3, 3], [1, 2, 3], [1, 2, 3, 3], [1, 3], [1, 3, 3], [2], [2, 2], [2, 2, 3], [2, 2, 3, 3], [2, 3], [2, 3, 3], [3], [3, 3]]
# After popping current: [3]
# After popping current: []
# [[],
#  [1],
#  [1, 2],
#  [1, 2, 2],
#  [1, 2, 2, 3],
#  [1, 2, 2, 3, 3],
#  [1, 2, 3],
#  [1, 2, 3, 3],
#  [1, 3],
#  [1, 3, 3],
#  [2],
#  [2, 2],
#  [2, 2, 3],
#  [2, 2, 3, 3],
#  [2, 3],
#  [2, 3, 3],
#  [3],
#  [3, 3]]

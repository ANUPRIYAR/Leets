# %% [markdown]
# <h2><a href="https://leetcode.com/problems/palindrome-partitioning">131. Palindrome Partitioning</a></h2><h3>Medium</h3><hr><p>Given a string <code>s</code>, partition <code>s</code> such that every <span data-keyword="substring-nonempty">substring</span> of the partition is a <span data-keyword="palindrome-string"><strong>palindrome</strong></span>. Return <em>all possible palindrome partitioning of </em><code>s</code>.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
# <pre><strong>Input:</strong> s = "aab"
# <strong>Output:</strong> [["a","a","b"],["aa","b"]]
# </pre><p><strong class="example">Example 2:</strong></p>
# <pre><strong>Input:</strong> s = "a"
# <strong>Output:</strong> [["a"]]
# </pre>
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= s.length &lt;= 16</code></li>
# 	<li><code>s</code> contains only lowercase English letters.</li>
# </ul>

# %% [markdown]
# ![image.png](attachment:c65602d7-4f5b-44dc-9026-c99cbf8e1707.png)

# %%
from typing import List

class Solution:
    def partition(self, s: str) -> List[List[str]]:
        result = []
        self.find(s, 0, result, [])
        return result

    def find(self, s, start, result, current):
        if start == len(s):
            print(f"start reached at  {start} . Appending current {current}")
            result.append(current[:])
            return

        for i in range(start , len(s)):
            print(f"start at {start} , end index at {i} ")
            if self.is_palindrome(s, start, i):
                print(f"Appending substr : {s[start : i + 1]}")
                current.append(s[start : i + 1])
                self.find(s, i + 1, result, current)
                print(f"Backtracking: {s[start : i + 1]} ")
                current.pop()               


    def is_palindrome(self, s, start , end):
        while start <= end:
            if s[start] != s[end]:
                return False
            start += 1
            end -= 1
        return True

# %%
s = 'aabcaba'
sol = Solution()
sol.partition(s)
# Out:
# start at 0 , end index at 0
# Appending substr : a
# start at 1 , end index at 1
# Appending substr : a
# start at 2 , end index at 2
# Appending substr : b
# start at 3 , end index at 3
# Appending substr : c
# start at 4 , end index at 4
# Appending substr : a
# start at 5 , end index at 5
# Appending substr : b
# start at 6 , end index at 6
# Appending substr : a
# start reached at  7 . Appending current ['a', 'a', 'b', 'c', 'a', 'b', 'a']
# Backtracking: a
# Backtracking: b
# start at 5 , end index at 6
# Backtracking: a
# start at 4 , end index at 5
# start at 4 , end index at 6
# Appending substr : aba
# start reached at  7 . Appending current ['a', 'a', 'b', 'c', 'aba']
# Backtracking: aba
# Backtracking: c
# start at 3 , end index at 4
# start at 3 , end index at 5
# start at 3 , end index at 6
# Backtracking: b
# start at 2 , end index at 3
# start at 2 , end index at 4
# start at 2 , end index at 5
# start at 2 , end index at 6
# Backtracking: a
# start at 1 , end index at 2
# start at 1 , end index at 3
# start at 1 , end index at 4
# start at 1 , end index at 5
# start at 1 , end index at 6
# Backtracking: a
# start at 0 , end index at 1
# Appending substr : aa
# start at 2 , end index at 2
# Appending substr : b
# start at 3 , end index at 3
# Appending substr : c
# start at 4 , end index at 4
# Appending substr : a
# start at 5 , end index at 5
# Appending substr : b
# start at 6 , end index at 6
# Appending substr : a
# start reached at  7 . Appending current ['aa', 'b', 'c', 'a', 'b', 'a']
# Backtracking: a
# Backtracking: b
# start at 5 , end index at 6
# Backtracking: a
# start at 4 , end index at 5
# start at 4 , end index at 6
# Appending substr : aba
# start reached at  7 . Appending current ['aa', 'b', 'c', 'aba']
# Backtracking: aba
# Backtracking: c
# start at 3 , end index at 4
# start at 3 , end index at 5
# start at 3 , end index at 6
# Backtracking: b
# start at 2 , end index at 3
# start at 2 , end index at 4
# start at 2 , end index at 5
# start at 2 , end index at 6
# Backtracking: aa
# start at 0 , end index at 2
# start at 0 , end index at 3
# start at 0 , end index at 4
# start at 0 , end index at 5
# start at 0 , end index at 6
# [['a', 'a', 'b', 'c', 'a', 'b', 'a'],
#  ['a', 'a', 'b', 'c', 'aba'],
#  ['aa', 'b', 'c', 'a', 'b', 'a'],
#  ['aa', 'b', 'c', 'aba']]

# %% [markdown]
# <h2><a href="https://leetcode.com/problems/subsets">78. Subsets</a></h2><h3>Medium</h3><hr><p>Given an integer array <code>nums</code> of <strong>unique</strong> elements, return <em>all possible</em> <span data-keyword="subset"><em>subsets</em></span> <em>(the power set)</em>.</p>
#
# <p>The solution set <strong>must not</strong> contain duplicate subsets. Return the solution in <strong>any order</strong>.</p>
#
# <p>&nbsp;</p>
# <p><strong class="example">Example 1:</strong></p>
#
# <pre>
# <strong>Input:</strong> nums = [1,2,3]
# <strong>Output:</strong> [[],[1],[2],[1,2],[3],[1,3],[2,3],[1,2,3]]
# </pre>
#
# <p><strong class="example">Example 2:</strong></p>
#
# <pre>
# <strong>Input:</strong> nums = [0]
# <strong>Output:</strong> [[],[0]]
# </pre>
#
# <p>&nbsp;</p>
# <p><strong>Constraints:</strong></p>
#
# <ul>
# 	<li><code>1 &lt;= nums.length &lt;= 10</code></li>
# 	<li><code>-10 &lt;= nums[i] &lt;= 10</code></li>
# 	<li>All the numbers of&nbsp;<code>nums</code> are <strong>unique</strong>.</li>
# </ul>

# %% [markdown]
# ![image.png](attachment:76f38394-ed1b-4023-95af-634f66d053e6.png)

# %%
from typing import List
class Solution:
    def subsets(self, nums: List[int]) -> List[List[int]]:
        def backtrack(index, result, current):
            if index == len(nums):
                result.append(current[:])
                print(f"===>result: {result}")
                return

            # pick this
            current.append(nums[index])
            print(f"current: {current} , index : {index}")
            print(f"entering 1st backtrack call")
            backtrack(index + 1, result, current)
            current.pop()
            print(f"After popping: {current}")

            # not pick this 
            print(f"entering 2nd backtrack call, , At index: {index +1}")
            backtrack(index + 1, result, current)

        result = []
        backtrack(0, result, [])
        return result

# %%
nums = [1,2,3]
sol = Solution()
sol.subsets(nums)
# Out:
# current: [1] , index : 0
# entering 1st backtrack call
# current: [1, 2] , index : 1
# entering 1st backtrack call
# current: [1, 2, 3] , index : 2
# entering 1st backtrack call
# ===>result: [[1, 2, 3]]
# After popping: [1, 2]
# entering 2nd backtrack call, , At index: 3
# ===>result: [[1, 2, 3], [1, 2]]
# After popping: [1]
# entering 2nd backtrack call, , At index: 2
# current: [1, 3] , index : 2
# entering 1st backtrack call
# ===>result: [[1, 2, 3], [1, 2], [1, 3]]
# After popping: [1]
# entering 2nd backtrack call, , At index: 3
# ===>result: [[1, 2, 3], [1, 2], [1, 3], [1]]
# After popping: []
# entering 2nd backtrack call, , At index: 1
# current: [2] , index : 1
# entering 1st backtrack call
# current: [2, 3] , index : 2
# entering 1st backtrack call
# ===>result: [[1, 2, 3], [1, 2], [1, 3], [1], [2, 3]]
# After popping: [2]
# entering 2nd backtrack call, , At index: 3
# ===>result: [[1, 2, 3], [1, 2], [1, 3], [1], [2, 3], [2]]
# After popping: []
# ...

# %%
freq = dict.fromkeys(range(0,5),0)

# %%
freq
# Out:
# {0: 0, 1: 0, 2: 0, 3: 0, 4: 0}
